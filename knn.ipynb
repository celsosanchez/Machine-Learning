# %%
import pandas as pd
data = pd.read_csv('D:/Etudes/4EME/4MLSP/heart-disease/HeartDiseaseUCI.csv')
print(data)
# Out:
#      Unnamed: 0  age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  \
# 0             1   63    1   1       145   233    1        2      150      0
# 1             2   67    1   4       160   286    0        2      108      1
# 2             3   67    1   4       120   229    0        2      129      1
# 3             4   37    1   3       130   250    0        0      187      0
# 4             5   41    0   2       130   204    0        2      172      0
# ..          ...  ...  ...  ..       ...   ...  ...      ...      ...    ...
# 298         299   45    1   1       110   264    0        0      132      0
# 299         300   68    1   4       144   193    1        0      141      0
# 300         301   57    1   4       130   131    0        0      115      1
# 301         302   57    0   2       130   236    0        2      174      0
# 302         303   38    1   3       138   175    0        0      173      0
#
#      oldpeak  slope   ca  thal  num
# ...

# %%
data["num"] = data["num"].apply(lambda x: 1 if x> 0 else 0)

# %%
print(data["num"])
# Out:
# 0      0
# 1      1
# 2      1
# 3      0
# 4      0
#       ..
# 298    1
# 299    1
# 300    1
# 301    1
# 302    0
# Name: num, Length: 303, dtype: int64

# %%
data["num"].value_counts()
# Out:
# 0    164
# 1    139
# Name: num, dtype: int64

# %%
data.describe()
# Out:
#        Unnamed: 0         age         sex          cp    trestbps        chol  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean   152.000000   54.438944    0.679868    3.158416  131.689769  246.693069
# std     87.612784    9.038662    0.467299    0.960126   17.599748   51.776918
# min      1.000000   29.000000    0.000000    1.000000   94.000000  126.000000
# 25%     76.500000   48.000000    0.000000    3.000000  120.000000  211.000000
# 50%    152.000000   56.000000    1.000000    3.000000  130.000000  241.000000
# 75%    227.500000   61.000000    1.000000    4.000000  140.000000  275.000000
# max    303.000000   77.000000    1.000000    4.000000  200.000000  564.000000
#
#               fbs     restecg     thalach       exang     oldpeak       slope  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.148515    0.990099  149.607261    0.326733    1.039604    1.600660
# ...

# %%
data['chol'].describe()
# Out:
# count    303.000000
# mean     246.693069
# std       51.776918
# min      126.000000
# 25%      211.000000
# 50%      241.000000
# 75%      275.000000
# max      564.000000
# Name: chol, dtype: float64

# %%
for column in data:
 print("Colonne ", column)
 print(data[column].describe())
 print(data[column].value_counts(), "\n")
# Out:
# Colonne  Unnamed: 0
# count    303.000000
# mean     152.000000
# std       87.612784
# min        1.000000
# 25%       76.500000
# 50%      152.000000
# 75%      227.500000
# max      303.000000
# Name: Unnamed: 0, dtype: float64
# 303    1
# 95     1
# 97     1
# 98     1
# 99     1
#       ..
# 203    1
# 204    1
# 205    1
# 206    1
# 1      1
# Name: Unnamed: 0, Length: 303, dtype: int64
#
# Colonne  age
# count    303.000000
# mean      54.438944
# std        9.038662
# min       29.000000
# 25%       48.000000
# 50%       56.000000
# 75%       61.000000
# max       77.000000
# Name: age, dtype: float64
# 58    19
# 57    17
# 54    16
# 59    14
# 52    13
# 51    12
# 60    12
# 62    11
# 44    11
# 56    11
# 64    10
# 41    10
# 63     9
# 67     9
# 55     8
# 45     8
# 42     8
# 53     8
# 61     8
# 65     8
# 43     8
# 66     7
# 50     7
# 48     7
# 46     7
# 49     5
# 47     5
# 39     4
# 35     4
# 68     4
# 70     4
# 40     3
# 71     3
# 69     3
# ...

# %%
from scipy.stats.mstats import describe
describe(data["age"])
# Out:
# DescribeResult(nobs=array(303, dtype=int64), minmax=(masked_array(data=29,
#              mask=False,
#        fill_value=999999,
#             dtype=int64), masked_array(data=77,
#              mask=False,
#        fill_value=999999,
#             dtype=int64)), mean=54.43894389438944, variance=81.42779030378287, skewness=masked_array(data=-0.20802409,
#              mask=False,
#        fill_value=1e+20), kurtosis=-0.5345227201725988)

# %%
import seaborn as sns
sns.countplot(data["num"])
# Out:
# C:\Users\celso\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='num', ylabel='count'>

# %%
sns.displot(data["age"])

# %%
sns.boxplot(data["age"])
# Out:
# C:\Users\celso\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age'>

# %%
import matplotlib.pyplot as plt
sns.countplot(data=data, x='sex', hue='num')
plt.title('gender v/s heart disease\n')
# Out:
# Text(0.5, 1.0, 'gender v/s heart disease\n')

# %%
sns.boxplot(x=data["num"],y=data["age"])
# Out:
# <AxesSubplot:xlabel='num', ylabel='age'>

# %%
data
# Out:
#      Unnamed: 0  age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  \
# 0             1   63    1   1       145   233    1        2      150      0
# 1             2   67    1   4       160   286    0        2      108      1
# 2             3   67    1   4       120   229    0        2      129      1
# 3             4   37    1   3       130   250    0        0      187      0
# 4             5   41    0   2       130   204    0        2      172      0
# ..          ...  ...  ...  ..       ...   ...  ...      ...      ...    ...
# 298         299   45    1   1       110   264    0        0      132      0
# 299         300   68    1   4       144   193    1        0      141      0
# 300         301   57    1   4       130   131    0        0      115      1
# 301         302   57    0   2       130   236    0        2      174      0
# 302         303   38    1   3       138   175    0        0      173      0
#
#      oldpeak  slope   ca  thal  num
# ...

# %%
df = data 
data
# Out:
#      Unnamed: 0  age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  \
# 0             1   63    1   1       145   233    1        2      150      0
# 1             2   67    1   4       160   286    0        2      108      1
# 2             3   67    1   4       120   229    0        2      129      1
# 3             4   37    1   3       130   250    0        0      187      0
# 4             5   41    0   2       130   204    0        2      172      0
# ..          ...  ...  ...  ..       ...   ...  ...      ...      ...    ...
# 298         299   45    1   1       110   264    0        0      132      0
# 299         300   68    1   4       144   193    1        0      141      0
# 300         301   57    1   4       130   131    0        0      115      1
# 301         302   57    0   2       130   236    0        2      174      0
# 302         303   38    1   3       138   175    0        0      173      0
#
#      oldpeak  slope   ca  thal  num
# ...

# %%
#data_y = df["num"]
#data_x = df.drop("num",axis=1,inplace=False)
#data_x
#data_y

# %%
import numpy as np
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test =train_test_split( data_x,data_y, test_size=0.20, random_state=42)

# %%
X_test.shape
# Out:
# (61, 14)

# %%
 import numpy as np
 from sklearn.impute import SimpleImputer
 imp_mean = SimpleImputer(missing_values=np.nan, strategy='mean')

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
quantitativeTransformer = Pipeline([('si',SimpleImputer(missing_values=np.nan, strategy='mean')),('minmax',MinMaxScaler())])

# %%
categoricalTransformer = Pipeline([('imputer', SimpleImputer(strategy='most_frequent')),('OneHotEncoder', OneHotEncoder())])

# %%
quantitativeVariables = ['age', 'cp','trestbps', 'chol', 'thalach', 'oldpeak', 'ca']
categoricalVariables = ['restecg', 'slope', 'thal']

# %%
from sklearn.compose import ColumnTransformer
toBeRemoved = ['Unnamed: 0']
preprocessor = ColumnTransformer(remainder = 'passthrough',transformers=[
('quantitative', quantitativeTransformer, quantitativeVariables),
('categorical', categoricalTransformer, categoricalVariables),
('remove', 'drop', toBeRemoved)])

# %%
parrameters = {'n_neighbors': [3,5,7],'weights':['uniform','distance']}

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm, datasets
from sklearn.model_selection import GridSearchCV
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import MinMaxScaler
from sklearn.impute import SimpleImputer # remplace les valeurs manquantes
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder

y = df["num"]
X = df.drop(["num"], axis = 1)
X_train,X_test,Y_train,Y_test = train_test_split(X,y,test_size=0.20,random_state=0, stratify=y)

quantitativeVariables = ['age', 'cp','trestbps', 'chol', 'thalach', 'oldpeak', 'ca']
categoricalVariables = ['restecg', 'slope', 'thal']
toBeRemoved = ['Unnamed: 0']

# nan = not a number
quantitativeTransformer = Pipeline([
    ('SIQTT', SimpleImputer(missing_values=np.nan, strategy='mean')), 
    ('MMS', MinMaxScaler())])


categoricalTransformer = Pipeline([
    ('SIQLT', SimpleImputer(strategy='most_frequent')),
    ('OHE', OneHotEncoder(drop='first'))])


preprocessor = ColumnTransformer(remainder = 'passthrough',transformers=[
('quantitative', quantitativeTransformer, quantitativeVariables),
('categorical', categoricalTransformer, categoricalVariables),
('remove', 'drop', toBeRemoved)])


heartKNN = Pipeline(steps=[("preprocess",preprocessor),
                 ("KNN",KNeighborsClassifier())])
hyperKNN = {'KNN__n_neighbors':[2,3,4,5],'KNN__p':[1,2,3,4],'KNN__weights':['uniform','distance']}
gridKNN = GridSearchCV(heartKNN,hyperKNN,cv=3,scoring='recall')

gridKNN.fit(X_train,Y_train)
# Out:
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('preprocess',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('quantitative',
#                                                                          Pipeline(steps=[('SIQTT',
#                                                                                           SimpleImputer()),
#                                                                                          ('MMS',
#                                                                                           MinMaxScaler())]),
#                                                                          ['age',
#                                                                           'cp',
#                                                                           'trestbps',
# ...

# %%
bestKNN = gridKNN.best_estimator_
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('quantitative',
#                                                   Pipeline(steps=[('SIQTT',
#                                                                    SimpleImputer()),
#                                                                   ('MMS',
#                                                                    MinMaxScaler())]),
#                                                   ['age', 'cp', 'trestbps',
#                                                    'chol', 'thalach', 'oldpeak',
#                                                    'ca']),
#                                                  ('categorical',
#                                                   Pipeline(steps=[('SIQLT',
#                                                                    SimpleImputer(strategy='most_frequent')),
# ...

# %%
gridKNN.best_params_
# Out:
# {'KNN__n_neighbors': 3, 'KNN__p': 2, 'KNN__weights': 'uniform'}

# %%
bestKNN.score(X_test,Y_test)
# Out:
# 0.7704918032786885

# %%
y_predicted = bestKNN.predict(X_test)

# %%
from sklearn.svm import LinearSVC
heartSVM = Pipeline(steps=[
('preprocess' , preprocessor),
('SVM' , LinearSVC())])

# %%
hypersvm = {'SVM__C': [1,10,100,1000]}

# %%
gridSVM = GridSearchCV(heartSVM,hypersvm,cv=3,scoring='recall')

# %%
gridSVM.fit(X_train,Y_train)
# Out:
# C:\Users\celso\anaconda3\lib\site-packages\sklearn\svm\_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# C:\Users\celso\anaconda3\lib\site-packages\sklearn\svm\_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# C:\Users\celso\anaconda3\lib\site-packages\sklearn\svm\_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# C:\Users\celso\anaconda3\lib\site-packages\sklearn\svm\_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# ...

# %%
gridSVM.score(X_test,Y_test)
# Out:
# 0.7857142857142857
